# %% [markdown]
# # Imporing libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
from tensorflow import keras
import seaborn as sns
import os
import warnings
import yfinance as yf
from sklearn.preprocessing import MinMaxScaler
from datetime import datetime
warnings.filterwarnings("ignore")
pd.set_option('display.max_columns', None)
# Out:
# 2025-07-01 13:34:00.701540: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# ## Importing modules

# %%
# Importing modules
import sys
import os
# Add the src path to sys.path
sys.path.append(os.path.abspath('../src'))
from modules.data_and_graph import na_calculator, get_company_name

# %% [markdown]
# # Importing dataset

# %%
# delimiter = ',': Specifies that commas separate values in the CSV file.
# on_bad_lines = 'skip': Skips any malformed lines in the CSV file.
df = pd.read_csv('../data/all_stocks_5yr.csv', delimiter=',', on_bad_lines='skip')
df.iloc[:7]
# Out:
#          date   open   high    low  close    volume Name
# 0  2013-02-08  15.07  15.12  14.63  14.75   8407500  AAL
# 1  2013-02-11  14.89  15.01  14.26  14.46   8882000  AAL
# 2  2013-02-12  14.45  14.51  14.10  14.27   8126000  AAL
# 3  2013-02-13  14.30  14.94  14.25  14.66  10259500  AAL
# 4  2013-02-14  14.94  14.96  13.16  13.99  31879900  AAL
# 5  2013-02-15  13.93  14.61  13.93  14.50  15628000  AAL
# 6  2013-02-19  14.33  14.56  14.08  14.26  11354400  AAL

# %%
# Turning the code names into real company name
unique_tickers = df['Name'].unique()
ticker_to_name = {}
for ticker in unique_tickers:
    try:
        info = yf.Ticker(ticker).info
        name = info.get('longName')
        if name:
            ticker_to_name[ticker] = name
    except:
        pass  # skip if it fails
df['Company name'] = df['Name'].map(ticker_to_name)
df.to_csv('../data/all_stocks_5yr_Modified.csv', index = False)
df.iloc[:7]
# Out:
# HTTP Error 404:
# HTTP Error 404:
#          date   open   high    low  close    volume Name  \
# 0  2013-02-08  15.07  15.12  14.63  14.75   8407500  AAL
# 1  2013-02-11  14.89  15.01  14.26  14.46   8882000  AAL
# 2  2013-02-12  14.45  14.51  14.10  14.27   8126000  AAL
# 3  2013-02-13  14.30  14.94  14.25  14.66  10259500  AAL
# 4  2013-02-14  14.94  14.96  13.16  13.99  31879900  AAL
# 5  2013-02-15  13.93  14.61  13.93  14.50  15628000  AAL
# 6  2013-02-19  14.33  14.56  14.08  14.26  11354400  AAL
#
#                    Company name
# 0  American Airlines Group Inc.
# 1  American Airlines Group Inc.
# 2  American Airlines Group Inc.
# 3  American Airlines Group Inc.
# 4  American Airlines Group Inc.
# 5  American Airlines Group Inc.
# 6  American Airlines Group Inc.

# %%
# Checking the Nas and data type
na_calculator(df)
# Out:
#           NAMES  VALUE COUNT  PERCENTAGE (%) DATA TYPE
# 0  Company name        80070           12.93    object
# 1          open           11            0.00   float64
# 2           low            8            0.00   float64
# 3          high            8            0.00   float64
# 4          date            0            0.00    object
# 5         close            0            0.00   float64
# 6        volume            0            0.00     int64
# 7          Name            0            0.00    object

# %%
# There are some Nas, that are not representative for the size of the dataset.
# Turning the date into data type: Whenever we deal with the date or time feature, it should always be in the DateTime data type. 
# Removing the missing data as well
df['date'] = pd.to_datetime(df['date'])
df = df.dropna()
na_calculator(df)
# Out:
#           NAMES  VALUE COUNT  PERCENTAGE (%)       DATA TYPE
# 0          date            0             0.0  datetime64[ns]
# 1          open            0             0.0         float64
# 2          high            0             0.0         float64
# 3           low            0             0.0         float64
# 4         close            0             0.0         float64
# 5        volume            0             0.0           int64
# 6          Name            0             0.0          object
# 7  Company name            0             0.0          object

# %% [markdown]
# # Exploratory Data Analysis (EDA)

# %%
# Company code for stocks 
pd.Series({'No. Rows':df.shape[0], 'No. Columns':df.shape[1]})
# Out:
# No. Rows       538960
# No. Columns         8
# dtype: int64

# %%
# Number of companies
len(df['Name'].unique())
# Out:
# 438

# %%
# Visualising the behaviour of open and closed stock prices over 5 years.
companies = ['AAPL', 'AMD', 'FB', 'GOOGL', 'AMZN', 'NVDA', 'EBAY', 'CSCO', 'IBM']

plt.figure(figsize=(15, 8))
for index, company in enumerate(companies, 1):
    plt.subplot(3, 3, index)
    c = df[df['Name'] == company]

    # Get the real company name from the dictionary
    full_name = ticker_to_name.get(company, company)

    # Plotting open and close prices
    plt.plot(c['date'], c['close'], c='blue', label='Close', marker='+', alpha=0.7)
    plt.plot(c['date'], c['open'], c='orange', label='Open', marker='^', alpha=0.7)

    # Set the full name in the title
    plt.title(full_name)
    plt.legend()
    plt.tight_layout()
plt.savefig('../images/behaviour_of_open_and_closed_stock_prices_over_5_years.png')

# %%
# Plotting the volume of trade for these 9 stocks as well as a function of time.

plt.figure(figsize=(15, 8))
for index, company in enumerate(companies, 1):
    plt.subplot(3, 3, index)
    c = df[df['Name'] == company]
     # Get full company name from the dictionary
    full_name = ticker_to_name.get(company, company)
    
    # Plot the volume
    plt.plot(c['date'], c['volume'], c='purple', marker='*')
    
    # Use the real name in the title
    plt.title(f"{full_name} Volume")
    plt.tight_layout()
plt.savefig('../images/trade_for_these_9_stocks.png')

# %%
# Now let's analyse the data for Apple Stocks from 2013 to 2018.
apple = df[df['Name'] == 'AAPL']
prediction_range = apple.loc[(apple['date'] > datetime(2013,1,1))
 & (apple['date']<datetime(2018,1,1))]
plt.plot(apple['date'],apple['close'])
plt.xlabel("Date")
plt.ylabel("Close")
plt.title("Apple Stock Prices")
plt.savefig('../images/Apple_Stocks_from_2013_to_2018.png');

# %% [markdown]
# # Preparing the data for training and evaluation
# ## Splitting the data

# %%
# Manually defining a 95% train / 5% test split. Doing it like this since we need to preserve the order in the timeline
close_data = apple.filter(['close'])
dataset = close_data.values
training = int(np.ceil(len(dataset) * .95))

# %% [markdown]
# ## Scaling the data, preparing the X and y

# %%
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_data = scaler.fit_transform(dataset)
train_data = scaled_data[0:int(training), :]

# Preparing features and labels
x_train = []
y_train = []

for i in range(60, len(train_data)):
    x_train.append(train_data[i-60:i, 0])
    y_train.append(train_data[i, 0])

x_train, y_train = np.array(x_train), np.array(y_train)
x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], 1))

# %% [markdown]
# # Build LSTM network using TensorFlow

# %%
model = keras.models.Sequential()
model.add(keras.layers.LSTM(units=64,
                            return_sequences=True,
                            input_shape=(x_train.shape[1], 1)))
model.add(keras.layers.LSTM(units=64))
model.add(keras.layers.Dense(32))
model.add(keras.layers.Dropout(0.5))
model.add(keras.layers.Dense(1))
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 60, 64)         │        16,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 64)             │        33,024 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │            33 │
# ...

# %% [markdown]
# ## Model Compilation and Training

# %%
model.compile(optimizer='adam',
              loss='mean_squared_error')
history = model.fit(x_train,
                    y_train,
                    epochs=10)
# Out:
# Epoch 1/10
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 4s 29ms/step - loss: 0.0586
# Epoch 2/10
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.0092
# Epoch 3/10
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0094
# Epoch 4/10
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0088
# Epoch 5/10
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0070
# Epoch 6/10
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0076
# Epoch 7/10
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0075
# Epoch 8/10
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 0.0069
# Epoch 9/10
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0069
# Epoch 10/10
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0063

# %% [markdown]
# ## Creating testing data and making prediction

# %%
test_data = scaled_data[training - 60:, :]
x_test = []
y_test = dataset[training:, :]
for i in range(60, len(test_data)):
    x_test.append(test_data[i-60:i, 0])

x_test = np.array(x_test)
x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], 1))

predictions = model.predict(x_test)
predictions = scaler.inverse_transform(predictions)

mse = np.mean(((predictions - y_test) ** 2))
rmse = np.sqrt(mse)

print("MSE", np.around(mse, 2))
print("RMSE", np.around(np.sqrt(mse), 2))
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 210ms/step
# MSE 53.57
# RMSE 7.32

# %% [markdown]
# ## Visualising the predictions

# %%
train = apple[:training]
test = apple[training:]
test['Predictions'] = predictions

plt.figure(figsize=(10, 8))
plt.plot(train['date'], train['close'])
plt.plot(test['date'], test[['close', 'Predictions']])
plt.title('Apple Stock Close Price')
plt.xlabel('Date')
plt.ylabel("Close")
plt.legend(['Train', 'Test', 'Predictions']);
